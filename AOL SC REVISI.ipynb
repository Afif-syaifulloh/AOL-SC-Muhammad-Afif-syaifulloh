# %%
# no 1
import matplotlib.pyplot as plt
import numpy as np

# Production data dari January 2018 sampe December 2023
production_data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 
    2048, 2523, 2086, 2391, 2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 
    3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531, 
    3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422, 
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 
    4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 
    6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594, 
    7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933, 
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 
    10244, 10740, 10318, 10393, 10986, 10635, 10731, 11749, 11849, 12123, 
    12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162, 
    13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893, 
    16388, 16782, 16716, 17033, 16896, 17689
]

bulan = np.arange(1, 145)  #bikin array

plt.figure(figsize=(14, 7))
plt.plot(bulan, production_data, label='Produksi perbulan', color='b')
plt.xlabel('bulan')
plt.ylabel('Jumlah Produksi')
plt.title('Data Produksi Tas Bulanan dari Januari 2018 sampai dengan Desember 2023')
plt.legend()
plt.grid(True)
plt.show()

# %%
#no 2 revisi
import numpy as np
import matplotlib.pyplot as plt

# Provided data
y = [1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391, 2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531, 3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422, 4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933, 8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318, 10393, 10986, 10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162, 13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893, 16388, 16782, 16716, 17033, 16896, 17689]
x = list(range(1, len(y) + 1))  # Generate x values from 1 to length of y

def exponential_func(x, a, b):
    return a * np.exp(b * x)

def taylor_expansion(x, a, b, n_terms):
    approx = np.zeros_like(x, dtype=float)
    for n in range(n_terms):
        approx += (b**n) * (x**n) / np.math.factorial(n)
    return a * approx

x = np.array(x)
y = np.array(y)

y_log = np.log(y)

# Perform linear regression to estimate parameters a and b
A = np.vstack([x, np.ones_like(x)]).T
a_log, b_log = np.linalg.lstsq(A, y_log, rcond=None)[0]

# Calculate parameters a and b for the exponential model
a = np.exp(b_log)
b = a_log

print(f"a = {a}, b = {b}")

x_fit = np.linspace(1, len(y), 100)
y_fit_exp = exponential_func(x_fit, a, b)
y_fit_taylor = taylor_expansion(x_fit, a, b, 10)  # Using 10 terms for Taylor series

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='produksi tas', linestyle='-')
plt.plot(x_fit, y_fit_exp, 'r-', label='Exponential Fit')
plt.plot(x_fit, y_fit_taylor, 'g--', label='Taylor Series Approximation')
plt.xlabel('Bulan')
plt.ylabel('produksi tas')
plt.title('Pendekatan Deret Taylor dan Eksponensial untuk Data Produksi tas')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# a = 1937.0139340177047, b = 0.01534031593981852
# C:\Users\afif\AppData\Local\Temp\ipykernel_7496\1324374100.py:15: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   approx += (b**n) * (x**n) / np.math.factorial(n)

# %%
# no 3
import numpy as np
from scipy.optimize import fsolve

# Data produksi bulanan
y = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 
    2048, 2523, 2086, 2391, 2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 
    3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531, 
    3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422, 
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 
    4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 
    6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594, 
    7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933, 
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 
    10244, 10740, 10318, 10393, 10986, 10635, 10731, 11749, 11849, 12123, 
    12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162, 
    13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893, 
    16388, 16782, 16716, 17033, 16896, 17689
]

# Data bulan dari M1 hingga M144
x = np.array(range(1, len(y) + 1))

# Menentukan parameter a dan b untuk model eksponensial dengan regresi linier
y_log = np.log(y)
A = np.vstack([x, np.ones(len(x))]).T
a_log, b_log = np.linalg.lstsq(A, y_log, rcond=None)[0]

# Menentukan parameter untuk model eksponensial
a = np.exp(b_log)
b = a_log

# Fungsi deret Taylor untuk model eksponensial
def taylor_expansion(x, a, b, n_terms):
    approx = np.zeros_like(x, dtype=float)
    for n in range(n_terms):
        approx += (b**n) * (x**n) / np.math.factorial(n)
    return a * approx

# Fungsi untuk mencari kapan produksi melebihi kapasitas gudang
def find_exceed_capacity(x):
    return taylor_expansion(x, a, b, 10) - 25000

# Mencari bulan kapan produksi melebihi 25000
months_to_exceed_capacity = fsolve(find_exceed_capacity, 150)[0]

# Waktu untuk mulai membangun gudang baru (13 bulan sebelum melebihi kapasitas)
start_build_month = months_to_exceed_capacity - 13

# Mengonversi ke format tanggal yang terbaca (mulai dari Januari 2018)
start_build_year = 2018 + (start_build_month // 12)
start_build_month_remainder = start_build_month % 12
start_build_month_name = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"][int(start_build_month_remainder) - 1]

print(f"EGIER needs to start building the new warehouse by {start_build_month_name} {int(start_build_year)}.")
# Out:
# EGIER needs to start building the new warehouse by September 2030.
# C:\Users\afif\AppData\Local\Temp\ipykernel_7496\1410997288.py:38: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   approx += (b**n) * (x**n) / np.math.factorial(n)
